# %%
# =========================================================
# AUTONOMOUS PREPROCESSING MULTI-AGENT SYSTEM
# WITH DEBUGGER AGENT
# =========================================================

import os
import io
import sys
import traceback
import warnings
import logging

import pandas as pd
import numpy as np

from typing import (
    TypedDict,
    List,
    Optional
)

from dotenv import load_dotenv

from langchain_openai import ChatOpenAI

from langgraph.graph import (
    StateGraph,
    END
)

from rich.console import Console

from rich.panel import Panel

from rich.syntax import Syntax

from rich.table import Table

from rich import box


# =========================================================
# CONFIGURATION
# =========================================================

load_dotenv(".env")

OPENAI_API_KEY = os.getenv(
    "OPENAI_API_KEY"
)

DATASET_PATH = "dataset.csv"

OUTPUT_DATASET = "Final_Dataset.csv"


# =========================================================
# LOGGING
# =========================================================

logging.basicConfig(

    level=logging.INFO,

    format="%(asctime)s - %(levelname)s - %(message)s"
)

logger = logging.getLogger(__name__)

warnings.filterwarnings("ignore")

console = Console()


# =========================================================
# LOAD DATASET
# =========================================================

df = pd.read_csv(DATASET_PATH)

console.print(

    "\n[bold green]"
    "Dataset Loaded Successfully"
    "[/bold green]\n"
)


# =========================================================
# DATASET PREVIEW
# =========================================================

preview_table = Table(

    title="Dataset Preview",

    box=box.DOUBLE_EDGE
)

for col in df.columns:

    preview_table.add_column(col)

for _, row in df.head().iterrows():

    preview_table.add_row(
        *[str(i) for i in row]
    )

console.print(preview_table)


# =========================================================
# LLM
# =========================================================

llm = ChatOpenAI(

    model="gpt-6-astra",

    temperature=1
)


# =========================================================
# PREPROCESSING TASKS
# =========================================================

PREPROCESSING_TASKS = [

    "Display dataset summary",

    "Print rows, columns and column names",

    "Identify numerical and categorical columns",

    "Handle missing values",

    "Handle outliers using IQR only for numeric columns",

    "Find duplicate rows"
]


# =========================================================
# STATE
# =========================================================

class PreprocessingState(TypedDict):

    df: pd.DataFrame

    tasks: List[str]

    task_index: int

    current_task: str

    generated_code: str

    preprocessing_output: str

    preprocessing_error: Optional[str]

    retry_count: int

    max_retries: int

    debug_history: List[str]

    last_error: str


# =========================================================
# PLANNER AGENT
# =========================================================

def planner_agent(state):

    task_index = state["task_index"]

    task = state["tasks"][task_index]

    console.print(

        f"\n[bold cyan]"
        f"PREPROCESSING TASK "
        f"{task_index + 1}"
        f"[/bold cyan]"
    )

    console.print(

        f"[yellow]{task}[/yellow]"
    )

    return {

        "current_task": task
    }


# =========================================================
# CODER AGENT
# =========================================================

def coder_agent(state):

    task = state["current_task"]

    prompt = f"""
You are an expert Python preprocessing engineer.

Rules:
1. Dataframe name is df
2. Use pandas and numpy only
3. Do NOT reload dataset
4. Return executable Python code only
5. Print meaningful output
6. Update df if preprocessing is applied

Task:
{task}
"""

    response = llm.invoke(prompt)

    code = response.content.strip()

    code = code.replace(
        "```python",
        ""
    )

    code = code.replace(
        "```",
        ""
    )

    console.print(

        "\n[bold green]"
        "GENERATED CODE"
        "[/bold green]\n"
    )

    syntax = Syntax(

        code,

        "python",

        theme="monokai"
    )

    console.print(syntax)

    return {

        "generated_code": code
    }


# =========================================================
# EXECUTOR AGENT
# =========================================================

def executor_agent(state):

    code = state["generated_code"]

    dataframe = state["df"]

    local_vars = {

        "df": dataframe.copy(),

        "pd": pd,

        "np": np
    }

    buffer = io.StringIO()

    try:

        sys.stdout = buffer

        exec(code, {}, local_vars)

        sys.stdout = sys.__stdout__

        updated_df = local_vars.get(
            "df",
            dataframe
        )

        output = buffer.getvalue()

        console.print(

            Panel(

                output if output else "Execution Completed",

                title="Execution Output",

                style="bold green"
            )
        )

        return {

            "df": updated_df,

            "preprocessing_output": output,

            "preprocessing_error": None,

            "last_error": ""
        }

    except Exception:

        sys.stdout = sys.__stdout__

        error_message = traceback.format_exc()

        console.print(

            Panel(

                error_message,

                title="Execution Failed",

                style="bold red"
            )
        )

        return {

            "preprocessing_error": error_message,

            "last_error": error_message
        }


# =========================================================
# DEBUGGER AGENT
# =========================================================

def debugger_agent(state):

    console.print(

        "\n[bold red]"
        "DEBUGGER AGENT ACTIVATED"
        "[/bold red]"
    )

    task = state["current_task"]

    original_code = state["generated_code"]

    error_message = state["last_error"]

    debug_prompt = f"""
You are a senior Python debugging engineer.

Task:
{task}

Original Code:
{original_code}

Execution Error:
{error_message}

Rules:
1. Fix the error
2. Preserve original preprocessing logic
3. Dataframe name must remain df
4. Use pandas and numpy only
5. Return ONLY executable Python code
6. Do not explain anything
7. Handle numeric-only operations correctly
"""

    response = llm.invoke(debug_prompt)

    fixed_code = response.content.strip()

    fixed_code = fixed_code.replace(
        "```python",
        ""
    )

    fixed_code = fixed_code.replace(
        "```",
        ""
    )

    console.print(

        "\n[bold yellow]"
        "FIXED CODE GENERATED"
        "[/bold yellow]\n"
    )

    syntax = Syntax(

        fixed_code,

        "python",

        theme="monokai"
    )

    console.print(syntax)

    debug_history = state["debug_history"]

    debug_history.append(error_message)

    return {

        "generated_code": fixed_code,

        "retry_count":
        state["retry_count"] + 1,

        "debug_history": debug_history
    }


# =========================================================
# EXECUTION ROUTER
# =========================================================

def execution_router(state):

    # SUCCESS
    if state["preprocessing_error"] is None:

        return "checker_agent"

    # MAX RETRIES REACHED
    if state["retry_count"] >= state["max_retries"]:

        return END

    # SEND TO DEBUGGER
    return "debugger_agent"


# =========================================================
# CHECKER AGENT
# =========================================================

def checker_agent(state):

    console.print(

        "\n[bold green]"
        "TASK COMPLETED SUCCESSFULLY"
        "[/bold green]"
    )

    return {}


# =========================================================
# NEXT TASK AGENT
# =========================================================

def next_task_agent(state):

    return {

        "task_index":
        state["task_index"] + 1,

        "retry_count": 0
    }


# =========================================================
# PREPROCESSING ROUTER
# =========================================================

def preprocessing_router(state):

    next_index = state["task_index"] + 1

    if next_index >= len(state["tasks"]):

        return END

    return "planner_agent"


# =========================================================
# BUILD GRAPH
# =========================================================

builder = StateGraph(
    PreprocessingState
)


# =========================================================
# ADD NODES
# =========================================================

builder.add_node(
    "planner_agent",
    planner_agent
)

builder.add_node(
    "coder_agent",
    coder_agent
)

builder.add_node(
    "executor_agent",
    executor_agent
)

builder.add_node(
    "debugger_agent",
    debugger_agent
)

builder.add_node(
    "checker_agent",
    checker_agent
)

builder.add_node(
    "next_task_agent",
    next_task_agent
)


# =========================================================
# ENTRY POINT
# =========================================================

builder.set_entry_point(
    "planner_agent"
)


# =========================================================
# MAIN FLOW
# =========================================================

builder.add_edge(
    "planner_agent",
    "coder_agent"
)

builder.add_edge(
    "coder_agent",
    "executor_agent"
)


# =========================================================
# EXECUTION ROUTING
# =========================================================

builder.add_conditional_edges(

    "executor_agent",

    execution_router,

    {

        "checker_agent":
        "checker_agent",

        "debugger_agent":
        "debugger_agent",

        END: END
    }
)


# =========================================================
# DEBUG LOOP
# =========================================================

builder.add_edge(
    "debugger_agent",
    "executor_agent"
)


# =========================================================
# CONTINUE TASKS
# =========================================================

builder.add_edge(
    "checker_agent",
    "next_task_agent"
)

builder.add_conditional_edges(

    "next_task_agent",

    preprocessing_router,

    {

        "planner_agent":
        "planner_agent",

        END: END
    }
)


# =========================================================
# COMPILE GRAPH
# =========================================================

graph = builder.compile()


# =========================================================
# VISUALIZE GRAPH
# =========================================================

from IPython.display import (
    Image,
    display
)

graph_png = (
    graph.get_graph()
    .draw_mermaid_png()
)

display(Image(graph_png))

print(
    graph.get_graph().draw_ascii()
)
# Save image
with open("langgraph.png", "wb") as f:
    f.write(graph_png)

print("Graph image saved successfully!")

# Display image
display(Image(graph_png))

# =========================================================
# RUN GRAPH
# =========================================================

final_state = graph.invoke({

    "df": df,

    "tasks": PREPROCESSING_TASKS,

    "task_index": 0,

    "current_task": "",

    "generated_code": "",

    "preprocessing_output": "",

    "preprocessing_error": None,

    "retry_count": 0,

    "max_retries": 3,

    "debug_history": [],

    "last_error": ""

},
config={
    "recursion_limit": 100
})


# =========================================================
# SAVE FINAL DATASET
# =========================================================

final_state["df"].to_csv(

    OUTPUT_DATASET,

    index=False
)

console.print(

    "\n[bold green]"
    "AUTONOMOUS PREPROCESSING PIPELINE COMPLETED"
    "[/bold green]"
)
# Out:
# Dataset Loaded Successfully
#                         Dataset Preview
# ╔════════════╤═════════╤══════════╤═══════════════╤═══════════╗
# ║ date       │ sku     │ location │ quantity_sold │ inventory ║
# ╟────────────┼─────────┼──────────┼───────────────┼───────────╢
# ║ 2024-01-01 │ SKU_101 │ Chennai  │ 52.0          │ 120       ║
# ║ 2024-01-02 │ SKU_101 │ Chennai  │ 49.0          │ 115       ║
# ║ 2024-01-03 │ SKU_101 │ Chennai  │ nan           │ 110       ║
# ║ 2024-01-04 │ SKU_101 │ Chennai  │ 55.0          │ 105       ║
# ║ 2024-01-05 │ SKU_101 │ Chennai  │ 60.0          │ 100       ║
# ╚════════════╧═════════╧══════════╧═══════════════╧═══════════╝
#                                              +-----------+
#                                              | __start__ |
#                                              +-----------+
#                                                     *
#                                                     *
#                                                     *
#                                            +---------------+
#                                            | planner_agent |...
#                                            +---------------+   .......
#                                             **                        .......
#                                           **                                 .......
#                                         **                                          .......
#                               +-------------+                                              ....
#                               | coder_agent |                                                 .
#                               +-------------+                                                 .
#                                       *                                                       .
#                                       *                                                       .
#                                       *                                                       .
#                             +----------------+                                                .
#                             | executor_agent |                                                .
#                           ..+----------------+....                                            .
#                       ....            .           .....                                       .
#                  .....                .                ....                                   .
#               ...                     .                    .....                              .
# +----------------+           +---------------+                  ...                       .....
# | debugger_agent |           | checker_agent |                    .             ..........
# +----------------+           +---------------+                    .    .........
#                                       *                      ..........
#                                       *            ..........     .
#                                       *       .....               .
#                             +-----------------+                  ..
#                             | next_task_agent |                ..
#                             +-----------------+              ..
#                                             ...           ...
#                                                ..       ..
#                                                  ..   ..
#                                               +---------+
#                                               | __end__ |
#                                               +---------+
# Graph image saved successfully!
# PREPROCESSING TASK 1
# Display dataset summary
# 2026-09-09 16:15:58,866 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# GENERATED CODE
# import pandas as pd
# import numpy as np
#
# print("=== Dataset Shape ===")
# print(f"Rows: {df.shape[0]:,}")
# print(f"Columns: {df.shape[1]:,}")
#
# print("\n=== First 5 Rows ===")
# print(df.head().to_string())
#
# print("\n=== Column Summary ===")
# summary = pd.DataFrame({
#     "Column": df.columns,
#     "Data Type": df.dtypes.astype(str).to_numpy(),
#     "Non-Null Count": df.notna().sum().to_numpy(),
#     "Missing Count": df.isna().sum().to_numpy(),
#     "Missing (%)": (
#         df.isna().sum().to_numpy() / len(df) * 100
#         if len(df) else np.zeros(df.shape[1])
#     ),
# })
# summary["Missing (%)"] = summary["Missing (%)"].round(2)
# print(summary.to_string(index=False))
#
# print("\n=== Descriptive Statistics ===")
# if df.shape[1]:
#     print(df.describe(include="all").to_string())
# else:
#     print("No columns available.")
#
# print("\n=== Duplicate Rows ===")
# try:
#     print(f"Duplicate rows (excluding first occurrence): {df.duplicated().sum():,}")
# except TypeError:
#     print("Cannot count duplicate rows because some cells contain unhashable values.")
#
# print("\n=== Memory Usage ===")
# print(f"Total (including index): {df.memory_usage(index=True, deep=True).sum() / 1024**2:,.2f} MB")
#
# print("\nSummary complete. df was not modified.")
# ╭─────────────────────────────────────────────── Execution Output ────────────────────────────────────────────────╮
# │ === Dataset Shape ===                                                                                           │
# │ Rows: 30                                                                                                        │
# │ Columns: 5                                                                                                      │
# │                                                                                                                 │
# │ === First 5 Rows ===                                                                                            │
# │          date      sku location  quantity_sold  inventory                                                       │
# │ 0  2024-01-01  SKU_101  Chennai           52.0        120                                                       │
# │ 1  2024-01-02  SKU_101  Chennai           49.0        115                                                       │
# │ 2  2024-01-03  SKU_101  Chennai            NaN        110                                                       │
# │ 3  2024-01-04  SKU_101  Chennai           55.0        105                                                       │
# │ 4  2024-01-05  SKU_101  Chennai           60.0        100                                                       │
# │                                                                                                                 │
# │ === Column Summary ===                                                                                          │
# │        Column Data Type  Non-Null Count  Missing Count  Missing (%)                                             │
# │          date       str              30              0         0.00                                             │
# │           sku       str              30              0         0.00                                             │
# │      location       str              30              0         0.00                                             │
# │ quantity_sold   float64              28              2         6.67                                             │
# │     inventory     int64              30              0         0.00                                             │
# │                                                                                                                 │
# │ === Descriptive Statistics ===                                                                                  │
# │               date      sku location  quantity_sold   inventory                                                 │
# │ count           30       30       30      28.000000   30.000000                                                 │
# │ unique          30        1        1            NaN         NaN                                                 │
# │ top     2024-01-01  SKU_101  Chennai            NaN         NaN                                                 │
# │ freq             1       30       30            NaN         NaN                                                 │
# │ mean           NaN      NaN      NaN      81.964286   51.500000                                                 │
# │ std            NaN      NaN      NaN      95.572537   38.799884                                                 │
# │ min            NaN      NaN      NaN      -5.000000    0.000000                                                 │
# │ 25%            NaN      NaN      NaN      55.750000   16.250000                                                 │
# │ 50%            NaN      NaN      NaN      62.500000   47.500000                                                 │
# │ 75%            NaN      NaN      NaN      69.250000   83.750000                                                 │
# │ max            NaN      NaN      NaN     500.000000  120.000000                                                 │
# │                                                                                                                 │
# │ === Duplicate Rows ===                                                                                          │
# │ Duplicate rows (excluding first occurrence): 0                                                                  │
# │                                                                                                                 │
# │ === Memory Usage ===                                                                                            │
# │ Total (including index): 0.01 MB                                                                                │
# │                                                                                                                 │
# │ Summary complete. df was not modified.                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# TASK COMPLETED SUCCESSFULLY
# PREPROCESSING TASK 2
# Print rows, columns and column names
# 2026-09-09 16:16:00,806 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# GENERATED CODE
# print(f"Rows: {df.shape[0]}")
# print(f"Columns: {df.shape[1]}")
# print("Column names:", df.columns.tolist())
# ╭─────────────────────────────────────────────── Execution Output ────────────────────────────────────────────────╮
# │ Rows: 30                                                                                                        │
# │ Columns: 5                                                                                                      │
# │ Column names: ['date', 'sku', 'location', 'quantity_sold', 'inventory']                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# TASK COMPLETED SUCCESSFULLY
# PREPROCESSING TASK 3
# Identify numerical and categorical columns
# 2026-09-09 16:16:07,770 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# GENERATED CODE
# import pandas as pd
# import numpy as np
#
# numerical_columns = df.select_dtypes(include=[np.number]).columns.tolist()
# categorical_columns = df.select_dtypes(
#     include=["object", "category", "string", "bool"]
# ).columns.tolist()
#
# other_columns = [
#     col for col in df.columns
#     if col not in numerical_columns and col not in categorical_columns
# ]
#
# print(f"Numerical columns ({len(numerical_columns)}):")
# print(numerical_columns)
#
# print(f"\nCategorical columns ({len(categorical_columns)}):")
# print(categorical_columns)
#
# if other_columns:
#     print(f"\nOther columns, such as datetime ({len(other_columns)}):")
#     print(other_columns)
#
# print("\nClassification is based on existing dtypes; df was not modified.")
# ╭─────────────────────────────────────────────── Execution Failed ────────────────────────────────────────────────╮
# │ Traceback (most recent call last):                                                                              │
# │   File "/var/folders/pr/q76x9dw10ds6vb4_8y13__tr0000gn/T/ipykernel_13588/741379250.py", line 289, in            │
# │ executor_agent                                                                                                  │
# │     exec(code, {}, local_vars)                                                                                  │
# │   File "<string>", line 9, in <module>                                                                          │
# │   File "<string>", line 11, in <listcomp>                                                                       │
# │ NameError: name 'numerical_columns' is not defined                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# DEBUGGER AGENT ACTIVATED
# 2026-09-09 16:16:12,685 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# FIXED CODE GENERATED
# import pandas as pd
# import numpy as np
#
# numerical_columns = df.select_dtypes(include=[np.number]).columns.tolist()
# categorical_columns = df.select_dtypes(
#     include=["object", "category", "string", "bool"]
# ).columns.tolist()
#
# other_columns = []
# for col in df.columns:
#     if col not in numerical_columns and col not in categorical_columns:
#         other_columns.append(col)
#
# print(f"Numerical columns ({len(numerical_columns)}):")
# print(numerical_columns)
#
# print(f"\nCategorical columns ({len(categorical_columns)}):")
# print(categorical_columns)
#
# if other_columns:
#     print(f"\nOther columns, such as datetime ({len(other_columns)}):")
#     print(other_columns)
#
# print("\nClassification is based on existing dtypes; df was not modified.")
# ╭─────────────────────────────────────────────── Execution Output ────────────────────────────────────────────────╮
# │ Numerical columns (2):                                                                                          │
# │ ['quantity_sold', 'inventory']                                                                                  │
# │                                                                                                                 │
# │ Categorical columns (3):                                                                                        │
# │ ['date', 'sku', 'location']                                                                                     │
# │                                                                                                                 │
# │ Classification is based on existing dtypes; df was not modified.                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# TASK COMPLETED SUCCESSFULLY
# PREPROCESSING TASK 4
# Handle missing values
# 2026-09-09 16:16:32,755 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# GENERATED CODE
# import pandas as pd
# import numpy as np
#
# missing_before = int(df.isna().sum().sum())
# report = []
#
# for position, column in enumerate(df.columns):
#     series = df.iloc[:, position]
#     missing_count = int(series.isna().sum())
#
#     if missing_count == 0:
#         continue
#
#     dtype = series.dtype
#
#     if pd.api.types.is_bool_dtype(dtype):
#         modes = series.mode(dropna=True)
#         fill_value = modes.iloc[0] if not modes.empty else False
#         strategy = "mode" if not modes.empty else "fallback: False"
#
#     elif pd.api.types.is_numeric_dtype(dtype):
#         # Ignore infinities when computing the median; leave existing values unchanged.
#         valid = series.replace([np.inf, -np.inf], np.nan).dropna()
#         fill_value = valid.median() if not valid.empty else 0
#         strategy = "finite-value median" if not valid.empty else "fallback: 0"
#
#         # Nullable integer columns cannot store fractional medians.
#         if pd.api.types.is_integer_dtype(dtype) and fill_value % 1 != 0:
#             series = series.astype("Float64")
#
#     else:
#         modes = series.mode(dropna=True)
#
#         if not modes.empty:
#             fill_value = modes.iloc[0]
#             strategy = "mode"
#         elif pd.api.types.is_datetime64_any_dtype(dtype):
#             fill_value = pd.Timestamp(
#                 "1970-01-01", tz=getattr(dtype, "tz", None)
#             )
#             strategy = "fallback: Unix epoch"
#         elif pd.api.types.is_timedelta64_dtype(dtype):
#             fill_value = pd.Timedelta(0)
#             strategy = "fallback: zero duration"
#         else:
#             fill_value = "Missing"
#             strategy = "fallback: 'Missing'"
#
#         if isinstance(dtype, pd.CategoricalDtype):
#             if fill_value not in series.cat.categories:
#                 series = series.cat.add_categories([fill_value])
#
#     try:
#         filled = series.fillna(fill_value)
#     except (TypeError, ValueError):
#         # Support extension dtypes that cannot represent the fallback value.
#         filled = series.astype(object).fillna(fill_value)
#         strategy += "; converted to object"
#
#     # Positional assignment also supports duplicate column names.
#     df.isetitem(position, filled)
#
#     report.append({
#         "column_position": position,
#         "column": column,
#         "missing_filled": missing_count - int(filled.isna().sum()),
#         "strategy": strategy,
#         "fill_value": repr(fill_value),
#     })
#
# print(f"Missing values before: {missing_before:,}")
# print(f"Missing values after:  {int(df.isna().sum().sum()):,}")
# print(f"DataFrame shape: {df.shape}")
#
# if report:
#     print("\nImputation summary:")
#     print(pd.DataFrame(report).to_string(index=False))
#     print("\nFallback values were used where no suitable observed value existed.")
# else:
#     print("No missing values found; df was not changed.")
# ╭─────────────────────────────────────────────── Execution Output ────────────────────────────────────────────────╮
# │ Missing values before: 2                                                                                        │
# │ Missing values after:  0                                                                                        │
# │ DataFrame shape: (30, 5)                                                                                        │
# │                                                                                                                 │
# │ Imputation summary:                                                                                             │
# │  column_position        column  missing_filled            strategy       fill_value                             │
# │                3 quantity_sold               2 finite-value median np.float64(62.5)                             │
# │                                                                                                                 │
# │ Fallback values were used where no suitable observed value existed.                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# TASK COMPLETED SUCCESSFULLY
# PREPROCESSING TASK 5
# Handle outliers using IQR only for numeric columns
# 2026-09-09 16:16:50,988 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# GENERATED CODE
# import pandas as pd
# import numpy as np
#
# # Cap numeric outliers at Q1 - 1.5*IQR and Q3 + 1.5*IQR.
# # Rows are preserved; missing values remain missing.
# numeric_columns = df.select_dtypes(include="number").columns
# summary = []
#
# for column in numeric_columns:
#     series = df[column]
#
#     if (
#         pd.api.types.is_complex_dtype(series.dtype)
#         or pd.api.types.is_timedelta64_dtype(series.dtype)
#     ):
#         print(f"Skipped {column!r}: IQR requires real-valued numeric data.")
#         continue
#
#     values = series.astype("float64")
#     finite_values = values[np.isfinite(values)]
#
#     if finite_values.empty:
#         print(f"Skipped {column!r}: no finite numeric values.")
#         continue
#
#     q1, q3 = finite_values.quantile([0.25, 0.75])
#     iqr = q3 - q1
#     lower_bound = q1 - 1.5 * iqr
#     upper_bound = q3 + 1.5 * iqr
#
#     below = values < lower_bound
#     above = values > upper_bound
#     outlier_count = int((below | above).sum())
#
#     if outlier_count:
#         # Float output allows fractional IQR bounds, including for integer columns.
#         df[column] = values.clip(lower=lower_bound, upper=upper_bound)
#
#     summary.append({
#         "column": column,
#         "lower_bound": lower_bound,
#         "upper_bound": upper_bound,
#         "values_capped": outlier_count,
#     })
#
# if summary:
#     print("IQR outlier capping summary (1.5 × IQR):")
#     print(pd.DataFrame(summary).to_string(index=False))
#     print(f"\nTotal values capped: {sum(item['values_capped'] for item in summary)}")
#     print(f"Updated df shape: {df.shape}")
# else:
#     print("No eligible numeric columns to process; df is unchanged.")
# ╭─────────────────────────────────────────────── Execution Output ────────────────────────────────────────────────╮
# │ IQR outlier capping summary (1.5 × IQR):                                                                        │
# │        column  lower_bound  upper_bound  values_capped                                                          │
# │ quantity_sold         37.5         87.5              4                                                          │
# │     inventory        -85.0        185.0              0                                                          │
# │                                                                                                                 │
# │ Total values capped: 4                                                                                          │
# │ Updated df shape: (30, 5)                                                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# TASK COMPLETED SUCCESSFULLY
# AUTONOMOUS PREPROCESSING PIPELINE COMPLETED
